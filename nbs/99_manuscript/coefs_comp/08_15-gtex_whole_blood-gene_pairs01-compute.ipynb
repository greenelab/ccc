# %% [markdown]
# # Description

# %% [markdown]
# It selects one gene pair (see `Settings` below) and computes the correlation coefficients and p-values across all the tissues in GTEx.
# We do this to check whether one pattern found in whole blood also replicates in other tissues.

# %% [markdown]
# # Modules

# %%
import pandas as pd

from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
import seaborn as sns

from ccc import conf
from ccc.coef import ccc

# %% [markdown]
# # Settings

# %%
# this gene pair was originally found with ccc on whole blood
# interesting: https://clincancerres.aacrjournals.org/content/26/21/5567.figures-only
gene0_id, gene1_id = "ENSG00000147050.14", "ENSG00000067048.16"
gene0_symbol, gene1_symbol = "KDM6A", "DDX3Y"

CCC_PVALUE_N_PERMS = 1000000

# %% [markdown]
# # Paths

# %%
TISSUE_DIR = conf.GTEX["DATA_DIR"] / "data_by_tissue"
assert TISSUE_DIR.exists()

# %%
OUTPUT_DIR = (
    conf.GTEX["RESULTS_DIR"]
    / "other_tissues"
    / f"{gene0_symbol.lower()}_vs_{gene1_symbol.lower()}"
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
display(OUTPUT_DIR)
# Out:
# PosixPath('/opt/data/results/gtex_v8/other_tissues/kdm6a_vs_ddx3y')

# %% [markdown]
# # Data

# %% [markdown]
# ## GTEx metadata

# %%
gtex_metadata = pd.read_pickle(conf.GTEX["DATA_DIR"] / "gtex_v8-sample_metadata.pkl")

# %%
gtex_metadata.shape
# Out:
# (22951, 66)

# %%
gtex_metadata.head()
# Out:
#                                    SUBJID     SEX    AGE  DTHHRDY  SMATSSCR  \
# SAMPID
# GTEX-1117F-0003-SM-58Q7G       GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0003-SM-5DWSB       GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0003-SM-6WBT7       GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F  GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8  GTEX-1117F  Female  60-69      4.0       NaN
#
#                               SMCENTER SMPTHNTS  SMRIN   SMTS  \
# SAMPID
# GTEX-1117F-0003-SM-58Q7G            B1      NaN    NaN  Blood
# GTEX-1117F-0003-SM-5DWSB            B1      NaN    NaN  Blood
# GTEX-1117F-0003-SM-6WBT7            B1      NaN    NaN  Blood
# GTEX-1117F-0011-R10a-SM-AHZ7F   B1, A1      NaN    NaN  Brain
# GTEX-1117F-0011-R10b-SM-CYKQ8   B1, A1      NaN    7.2  Brain
#
#                                                       SMTSD  ... SME1ANTI  \
# SAMPID                                                       ...
# GTEX-1117F-0003-SM-58Q7G                        Whole Blood  ...      NaN
# GTEX-1117F-0003-SM-5DWSB                        Whole Blood  ...      NaN
# GTEX-1117F-0003-SM-6WBT7                        Whole Blood  ...      NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F  Brain - Frontal Cortex (BA9)  ...      NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8  Brain - Frontal Cortex (BA9)  ...      NaN
#
#                                SMSPLTRD  SMBSMMRT SME1SNSE SME1PCTS SMRRNART  \
# SAMPID
# GTEX-1117F-0003-SM-58Q7G            NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-5DWSB            NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-6WBT7            NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F       NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8       NaN       NaN      NaN      NaN      NaN
#
#                               SME1MPRT SMNUM5CD SMDPMPRT SME2PCTS
# SAMPID
# GTEX-1117F-0003-SM-58Q7G           NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-5DWSB           NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-6WBT7           NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F      NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8      NaN      NaN      NaN      NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Gene Ensembl ID -> Symbol mapping

# %%
gene_map = pd.read_pickle(conf.GTEX["DATA_DIR"] / "gtex_gene_id_symbol_mappings.pkl")

# %%
gene_map = gene_map.set_index("gene_ens_id")["gene_symbol"].to_dict()

# %%
assert gene_map["ENSG00000145309.5"] == "CABS1"

# %%
assert gene_map[gene0_id] == gene0_symbol
assert gene_map[gene1_id] == gene1_symbol

# %% [markdown]
# # Compute correlation on all tissues

# %%
res_all = pd.DataFrame(
    {
        f.stem.split("_data_")[1]: {
            "cm": ccc(data[gene0_id], data[gene1_id]),
            "pearson": pearsonr(data[gene0_id], data[gene1_id])[0],
            "spearman": spearmanr(data[gene0_id], data[gene1_id])[0],
        }
        for f in TISSUE_DIR.glob("*.pkl")
        if (data := pd.read_pickle(f).T[[gene0_id, gene1_id]].dropna()) is not None
        and data.shape[0] > 10
    }
).T.abs()

# %%
res_all.shape
# Out:
# (50, 3)

# %%
res_all.head()
# Out:
#                         cm   pearson  spearman
# colon_transverse  0.280814  0.393881  0.465898
# brain_amygdala    0.305677  0.038732  0.154331
# artery_coronary   0.242720  0.487610  0.426164
# artery_aorta      0.381970  0.579236  0.409761
# adrenal_gland     0.188929  0.489400  0.418784

# %%
res_all.sort_values("cm")
# Out:
#                                              cm   pearson  spearman
# testis                                 0.006332  0.017759  0.028708
# ovary                                  0.016698  0.100520  0.125249
# vagina                                 0.016935  0.080397  0.190372
# uterus                                 0.025004  0.078480  0.228621
# bladder                                0.089510  0.440277  0.216883
# small_intestine_terminal_ileum         0.164531  0.361532  0.436642
# brain_spinal_cord_cervical_c1          0.166019  0.119269  0.067168
# prostate                               0.166530  0.576071  0.614194
# stomach                                0.172034  0.364280  0.453740
# adrenal_gland                          0.188929  0.489400  0.418784
# whole_blood                            0.193557  0.237462  0.035350
# adipose_visceral_omentum               0.194845  0.289887  0.137254
# brain_cortex                           0.198577  0.156560  0.107833
# skin_not_sun_exposed_suprapubic        0.207350  0.370123  0.265796
# pituitary                              0.212682  0.534453  0.289150
# skin_sun_exposed_lower_leg             0.213732  0.390535  0.303231
# pancreas                               0.217250  0.306640  0.249611
# brain_hippocampus                      0.218583  0.192953  0.297004
# brain_cerebellum                       0.219113  0.106469  0.034902
# brain_substantia_nigra                 0.221853  0.285203  0.278507
# kidney_cortex                          0.223916  0.171881  0.205941
# heart_left_ventricle                   0.226687  0.191436  0.031302
# minor_salivary_gland                   0.230149  0.493186  0.273789
# brain_anterior_cingulate_cortex_ba24   0.231620  0.034852  0.188542
# brain_hypothalamus                     0.232632  0.118391  0.251149
# heart_atrial_appendage                 0.233004  0.080692  0.049178
# artery_coronary                        0.242720  0.487610  0.426164
# brain_putamen_basal_ganglia            0.244480  0.124198  0.244834
# spleen                                 0.244719  0.463024  0.381976
# brain_cerebellar_hemisphere            0.254950  0.169581  0.276677
# brain_frontal_cortex_ba9               0.254996  0.054030  0.186901
# colon_transverse                       0.280814  0.393881  0.465898
# esophagus_mucosa                       0.284517  0.434191  0.388334
# brain_caudate_basal_ganglia            0.286423  0.171409  0.215178
# lung                                   0.289771  0.252442  0.224470
# artery_tibial                          0.298440  0.617718  0.387765
# brain_nucleus_accumbens_basal_ganglia  0.301435  0.231078  0.261622
# muscle_skeletal                        0.302324  0.252692  0.183798
# cells_cultured_fibroblasts             0.302399  0.694025  0.592887
# brain_amygdala                         0.305677  0.038732  0.154331
# esophagus_gastroesophageal_junction    0.311840  0.428251  0.266577
# breast_mammary_tissue                  0.312518  0.442520  0.307113
# thyroid                                0.326157  0.550632  0.428463
# adipose_subcutaneous                   0.331717  0.482327  0.320547
# liver                                  0.347885  0.304891  0.218744
# nerve_tibial                           0.374104  0.647834  0.403768
# artery_aorta                           0.381970  0.579236  0.409761
# esophagus_muscularis                   0.391141  0.492280  0.366355
# cells_ebvtransformed_lymphocytes       0.407538  0.411400  0.371905
# colon_sigmoid                          0.408355  0.529455  0.414515

# %%
res_all.sort_values("pearson")
# Out:
#                                              cm   pearson  spearman
# testis                                 0.006332  0.017759  0.028708
# brain_anterior_cingulate_cortex_ba24   0.231620  0.034852  0.188542
# brain_amygdala                         0.305677  0.038732  0.154331
# brain_frontal_cortex_ba9               0.254996  0.054030  0.186901
# uterus                                 0.025004  0.078480  0.228621
# vagina                                 0.016935  0.080397  0.190372
# heart_atrial_appendage                 0.233004  0.080692  0.049178
# ovary                                  0.016698  0.100520  0.125249
# brain_cerebellum                       0.219113  0.106469  0.034902
# brain_hypothalamus                     0.232632  0.118391  0.251149
# brain_spinal_cord_cervical_c1          0.166019  0.119269  0.067168
# brain_putamen_basal_ganglia            0.244480  0.124198  0.244834
# brain_cortex                           0.198577  0.156560  0.107833
# brain_cerebellar_hemisphere            0.254950  0.169581  0.276677
# brain_caudate_basal_ganglia            0.286423  0.171409  0.215178
# kidney_cortex                          0.223916  0.171881  0.205941
# heart_left_ventricle                   0.226687  0.191436  0.031302
# brain_hippocampus                      0.218583  0.192953  0.297004
# brain_nucleus_accumbens_basal_ganglia  0.301435  0.231078  0.261622
# whole_blood                            0.193557  0.237462  0.035350
# lung                                   0.289771  0.252442  0.224470
# muscle_skeletal                        0.302324  0.252692  0.183798
# brain_substantia_nigra                 0.221853  0.285203  0.278507
# adipose_visceral_omentum               0.194845  0.289887  0.137254
# liver                                  0.347885  0.304891  0.218744
# pancreas                               0.217250  0.306640  0.249611
# small_intestine_terminal_ileum         0.164531  0.361532  0.436642
# stomach                                0.172034  0.364280  0.453740
# skin_not_sun_exposed_suprapubic        0.207350  0.370123  0.265796
# skin_sun_exposed_lower_leg             0.213732  0.390535  0.303231
# colon_transverse                       0.280814  0.393881  0.465898
# cells_ebvtransformed_lymphocytes       0.407538  0.411400  0.371905
# esophagus_gastroesophageal_junction    0.311840  0.428251  0.266577
# esophagus_mucosa                       0.284517  0.434191  0.388334
# bladder                                0.089510  0.440277  0.216883
# breast_mammary_tissue                  0.312518  0.442520  0.307113
# spleen                                 0.244719  0.463024  0.381976
# adipose_subcutaneous                   0.331717  0.482327  0.320547
# artery_coronary                        0.242720  0.487610  0.426164
# adrenal_gland                          0.188929  0.489400  0.418784
# esophagus_muscularis                   0.391141  0.492280  0.366355
# minor_salivary_gland                   0.230149  0.493186  0.273789
# colon_sigmoid                          0.408355  0.529455  0.414515
# pituitary                              0.212682  0.534453  0.289150
# thyroid                                0.326157  0.550632  0.428463
# prostate                               0.166530  0.576071  0.614194
# artery_aorta                           0.381970  0.579236  0.409761
# artery_tibial                          0.298440  0.617718  0.387765
# nerve_tibial                           0.374104  0.647834  0.403768
# cells_cultured_fibroblasts             0.302399  0.694025  0.592887

# %%
res_all.sort_values("spearman")
# Out:
#                                              cm   pearson  spearman
# testis                                 0.006332  0.017759  0.028708
# heart_left_ventricle                   0.226687  0.191436  0.031302
# brain_cerebellum                       0.219113  0.106469  0.034902
# whole_blood                            0.193557  0.237462  0.035350
# heart_atrial_appendage                 0.233004  0.080692  0.049178
# brain_spinal_cord_cervical_c1          0.166019  0.119269  0.067168
# brain_cortex                           0.198577  0.156560  0.107833
# ovary                                  0.016698  0.100520  0.125249
# adipose_visceral_omentum               0.194845  0.289887  0.137254
# brain_amygdala                         0.305677  0.038732  0.154331
# muscle_skeletal                        0.302324  0.252692  0.183798
# brain_frontal_cortex_ba9               0.254996  0.054030  0.186901
# brain_anterior_cingulate_cortex_ba24   0.231620  0.034852  0.188542
# vagina                                 0.016935  0.080397  0.190372
# kidney_cortex                          0.223916  0.171881  0.205941
# brain_caudate_basal_ganglia            0.286423  0.171409  0.215178
# bladder                                0.089510  0.440277  0.216883
# liver                                  0.347885  0.304891  0.218744
# lung                                   0.289771  0.252442  0.224470
# uterus                                 0.025004  0.078480  0.228621
# brain_putamen_basal_ganglia            0.244480  0.124198  0.244834
# pancreas                               0.217250  0.306640  0.249611
# brain_hypothalamus                     0.232632  0.118391  0.251149
# brain_nucleus_accumbens_basal_ganglia  0.301435  0.231078  0.261622
# skin_not_sun_exposed_suprapubic        0.207350  0.370123  0.265796
# esophagus_gastroesophageal_junction    0.311840  0.428251  0.266577
# minor_salivary_gland                   0.230149  0.493186  0.273789
# brain_cerebellar_hemisphere            0.254950  0.169581  0.276677
# brain_substantia_nigra                 0.221853  0.285203  0.278507
# pituitary                              0.212682  0.534453  0.289150
# brain_hippocampus                      0.218583  0.192953  0.297004
# skin_sun_exposed_lower_leg             0.213732  0.390535  0.303231
# breast_mammary_tissue                  0.312518  0.442520  0.307113
# adipose_subcutaneous                   0.331717  0.482327  0.320547
# esophagus_muscularis                   0.391141  0.492280  0.366355
# cells_ebvtransformed_lymphocytes       0.407538  0.411400  0.371905
# spleen                                 0.244719  0.463024  0.381976
# artery_tibial                          0.298440  0.617718  0.387765
# esophagus_mucosa                       0.284517  0.434191  0.388334
# nerve_tibial                           0.374104  0.647834  0.403768
# artery_aorta                           0.381970  0.579236  0.409761
# colon_sigmoid                          0.408355  0.529455  0.414515
# adrenal_gland                          0.188929  0.489400  0.418784
# artery_coronary                        0.242720  0.487610  0.426164
# thyroid                                0.326157  0.550632  0.428463
# small_intestine_terminal_ileum         0.164531  0.361532  0.436642
# stomach                                0.172034  0.364280  0.453740
# colon_transverse                       0.280814  0.393881  0.465898
# cells_cultured_fibroblasts             0.302399  0.694025  0.592887
# prostate                               0.166530  0.576071  0.614194

# %% [markdown]
# # Compute p-values on all tissues

# %%
res_pval_all = pd.DataFrame(
    {
        f.stem.split("_data_")[1]: {
            "cm": ccc(
                data[gene0_id],
                data[gene1_id],
                pvalue_n_perms=CCC_PVALUE_N_PERMS,
                n_jobs=conf.GENERAL["N_JOBS"],
            )[1],
            "pearson": pearsonr(data[gene0_id], data[gene1_id])[1],
            "spearman": spearmanr(data[gene0_id], data[gene1_id])[1],
        }
        for f in TISSUE_DIR.glob("*.pkl")
        if (data := pd.read_pickle(f).T[[gene0_id, gene1_id]].dropna()) is not None
        and data.shape[0] > 10
    }
).T.abs()

# %%
res_pval_all.shape
# Out:
# (50, 3)

# %%
res_pval_all.head()
# Out:
#                             cm       pearson      spearman
# colon_transverse  9.999990e-07  1.613504e-16  2.880714e-23
# brain_amygdala    9.999990e-07  6.356755e-01  5.764275e-02
# artery_coronary   9.999990e-07  9.731623e-16  5.220895e-12
# artery_aorta      9.999990e-07  4.513966e-40  6.380372e-19
# adrenal_gland     9.999990e-07  6.058615e-17  2.230048e-12

# %%
res_pval_all.sort_values("cm")
# Out:
#                                                  cm       pearson  \
# colon_transverse                       9.999990e-07  1.613504e-16
# prostate                               9.999990e-07  4.637571e-23
# brain_frontal_cortex_ba9               9.999990e-07  4.371643e-01
# brain_caudate_basal_ganglia            9.999990e-07  7.044831e-03
# muscle_skeletal                        9.999990e-07  3.656202e-13
# stomach                                9.999990e-07  1.045907e-12
# skin_not_sun_exposed_suprapubic        9.999990e-07  4.784340e-21
# adipose_visceral_omentum               9.999990e-07  6.191569e-12
# nerve_tibial                           9.999990e-07  6.073870e-75
# pancreas                               9.999990e-07  1.432674e-08
# brain_cerebellum                       9.999990e-07  9.916004e-02
# breast_mammary_tissue                  9.999990e-07  1.971106e-23
# brain_nucleus_accumbens_basal_ganglia  9.999990e-07  2.567349e-04
# minor_salivary_gland                   9.999990e-07  2.601462e-11
# esophagus_muscularis                   9.999990e-07  8.650204e-33
# thyroid                                9.999990e-07  4.844271e-53
# small_intestine_terminal_ileum         9.999990e-07  3.700708e-07
# cells_cultured_fibroblasts             9.999990e-07  1.188516e-73
# artery_tibial                          9.999990e-07  5.248493e-71
# brain_hypothalamus                     9.999990e-07  9.332407e-02
# lung                                   9.999990e-07  7.462864e-10
# spleen                                 9.999990e-07  3.291874e-14
# esophagus_mucosa                       9.999990e-07  6.374962e-27
# brain_spinal_cord_cervical_c1          9.999990e-07  1.342873e-01
# pituitary                              9.999990e-07  2.635795e-22
# brain_amygdala                         9.999990e-07  6.356755e-01
# artery_coronary                        9.999990e-07  9.731623e-16
# artery_aorta                           9.999990e-07  4.513966e-40
# adrenal_gland                          9.999990e-07  6.058615e-17
# brain_substantia_nigra                 9.999990e-07  6.662844e-04
# brain_cortex                           9.999990e-07  1.230662e-02
# brain_anterior_cingulate_cortex_ba24   9.999990e-07  6.460824e-01
# brain_cerebellar_hemisphere            9.999990e-07  1.277016e-02
# heart_left_ventricle                   9.999990e-07  6.215317e-05
# brain_putamen_basal_ganglia            9.999990e-07  7.602316e-02
# brain_hippocampus                      9.999990e-07  6.596327e-03
# esophagus_gastroesophageal_junction    9.999990e-07  3.706506e-18
# liver                                  9.999990e-07  3.015460e-06
# skin_sun_exposed_lower_leg             9.999990e-07  5.836576e-27
# heart_atrial_appendage                 9.999990e-07  9.508466e-02
# whole_blood                            9.999990e-07  3.875814e-11
# adipose_subcutaneous                   9.999990e-07  6.287645e-40
# cells_ebvtransformed_lymphocytes       9.999990e-07  1.706982e-08
# colon_sigmoid                          9.999990e-07  2.450898e-28
# kidney_cortex                          2.999997e-06  1.157355e-01
# uterus                                 2.868027e-01  3.532197e-01
# ovary                                  4.256326e-01  1.793916e-01
# vagina                                 5.256995e-01  3.184237e-01
# bladder                                5.584744e-01  4.577874e-02
# testis                                 6.282804e-01  7.366585e-01
#
#                                            spearman
# colon_transverse                       2.880714e-23
# prostate                               8.471438e-27
# brain_frontal_cortex_ba9               6.734313e-03
# brain_caudate_basal_ganglia            6.797072e-04
# muscle_skeletal                        1.563020e-07
# stomach                                1.240450e-19
# skin_not_sun_exposed_suprapubic        3.167647e-11
# adipose_visceral_omentum               1.373269e-03
# nerve_tibial                           1.130228e-25
# pancreas                               4.739023e-06
# brain_cerebellum                       5.897648e-01
# breast_mammary_tissue                  1.756788e-11
# brain_nucleus_accumbens_basal_ganglia  3.251833e-05
# minor_salivary_gland                   4.228621e-04
# esophagus_muscularis                   8.375537e-18
# thyroid                                1.541651e-30
# small_intestine_terminal_ileum         4.174152e-10
# cells_cultured_fibroblasts             3.662235e-49
# artery_tibial                          3.246061e-25
# brain_hypothalamus                     3.117929e-04
# lung                                   4.905714e-08
# spleen                                 8.614195e-10
# esophagus_mucosa                       2.030847e-21
# brain_spinal_cord_cervical_c1          4.002211e-01
# pituitary                              7.465807e-07
# brain_amygdala                         5.764275e-02
# artery_coronary                        5.220895e-12
# artery_aorta                           6.380372e-19
# adrenal_gland                          2.230048e-12
# brain_substantia_nigra                 9.007222e-04
# brain_cortex                           8.570472e-02
# brain_anterior_cingulate_cortex_ba24   1.221116e-02
# brain_cerebellar_hemisphere            3.891439e-05
# heart_left_ventricle                   5.164202e-01
# brain_putamen_basal_ganglia            4.030928e-04
# brain_hippocampus                      2.253662e-05
# esophagus_gastroesophageal_junction    1.604572e-07
# liver                                  9.316583e-04
# skin_sun_exposed_lower_leg             2.245602e-16
# heart_atrial_appendage                 3.095176e-01
# whole_blood                            3.320333e-01
# adipose_subcutaneous                   2.618709e-17
# cells_ebvtransformed_lymphocytes       4.352944e-07
# colon_sigmoid                          6.395478e-17
# kidney_cortex                          5.863872e-02
# uterus                                 6.207795e-03
# ovary                                  9.387668e-02
# vagina                                 1.729214e-02
# bladder                                3.450003e-01
# testis                                 5.866689e-01

# %%
res_pval_all.sort_values("pearson")
# Out:
#                                                  cm       pearson  \
# nerve_tibial                           9.999990e-07  6.073870e-75
# cells_cultured_fibroblasts             9.999990e-07  1.188516e-73
# artery_tibial                          9.999990e-07  5.248493e-71
# thyroid                                9.999990e-07  4.844271e-53
# artery_aorta                           9.999990e-07  4.513966e-40
# adipose_subcutaneous                   9.999990e-07  6.287645e-40
# esophagus_muscularis                   9.999990e-07  8.650204e-33
# colon_sigmoid                          9.999990e-07  2.450898e-28
# skin_sun_exposed_lower_leg             9.999990e-07  5.836576e-27
# esophagus_mucosa                       9.999990e-07  6.374962e-27
# breast_mammary_tissue                  9.999990e-07  1.971106e-23
# prostate                               9.999990e-07  4.637571e-23
# pituitary                              9.999990e-07  2.635795e-22
# skin_not_sun_exposed_suprapubic        9.999990e-07  4.784340e-21
# esophagus_gastroesophageal_junction    9.999990e-07  3.706506e-18
# adrenal_gland                          9.999990e-07  6.058615e-17
# colon_transverse                       9.999990e-07  1.613504e-16
# artery_coronary                        9.999990e-07  9.731623e-16
# spleen                                 9.999990e-07  3.291874e-14
# muscle_skeletal                        9.999990e-07  3.656202e-13
# stomach                                9.999990e-07  1.045907e-12
# adipose_visceral_omentum               9.999990e-07  6.191569e-12
# minor_salivary_gland                   9.999990e-07  2.601462e-11
# whole_blood                            9.999990e-07  3.875814e-11
# lung                                   9.999990e-07  7.462864e-10
# pancreas                               9.999990e-07  1.432674e-08
# cells_ebvtransformed_lymphocytes       9.999990e-07  1.706982e-08
# small_intestine_terminal_ileum         9.999990e-07  3.700708e-07
# liver                                  9.999990e-07  3.015460e-06
# heart_left_ventricle                   9.999990e-07  6.215317e-05
# brain_nucleus_accumbens_basal_ganglia  9.999990e-07  2.567349e-04
# brain_substantia_nigra                 9.999990e-07  6.662844e-04
# brain_hippocampus                      9.999990e-07  6.596327e-03
# brain_caudate_basal_ganglia            9.999990e-07  7.044831e-03
# brain_cortex                           9.999990e-07  1.230662e-02
# brain_cerebellar_hemisphere            9.999990e-07  1.277016e-02
# bladder                                5.584744e-01  4.577874e-02
# brain_putamen_basal_ganglia            9.999990e-07  7.602316e-02
# brain_hypothalamus                     9.999990e-07  9.332407e-02
# heart_atrial_appendage                 9.999990e-07  9.508466e-02
# brain_cerebellum                       9.999990e-07  9.916004e-02
# kidney_cortex                          2.999997e-06  1.157355e-01
# brain_spinal_cord_cervical_c1          9.999990e-07  1.342873e-01
# ovary                                  4.256326e-01  1.793916e-01
# vagina                                 5.256995e-01  3.184237e-01
# uterus                                 2.868027e-01  3.532197e-01
# brain_frontal_cortex_ba9               9.999990e-07  4.371643e-01
# brain_amygdala                         9.999990e-07  6.356755e-01
# brain_anterior_cingulate_cortex_ba24   9.999990e-07  6.460824e-01
# testis                                 6.282804e-01  7.366585e-01
#
#                                            spearman
# nerve_tibial                           1.130228e-25
# cells_cultured_fibroblasts             3.662235e-49
# artery_tibial                          3.246061e-25
# thyroid                                1.541651e-30
# artery_aorta                           6.380372e-19
# adipose_subcutaneous                   2.618709e-17
# esophagus_muscularis                   8.375537e-18
# colon_sigmoid                          6.395478e-17
# skin_sun_exposed_lower_leg             2.245602e-16
# esophagus_mucosa                       2.030847e-21
# breast_mammary_tissue                  1.756788e-11
# prostate                               8.471438e-27
# pituitary                              7.465807e-07
# skin_not_sun_exposed_suprapubic        3.167647e-11
# esophagus_gastroesophageal_junction    1.604572e-07
# adrenal_gland                          2.230048e-12
# colon_transverse                       2.880714e-23
# artery_coronary                        5.220895e-12
# spleen                                 8.614195e-10
# muscle_skeletal                        1.563020e-07
# stomach                                1.240450e-19
# adipose_visceral_omentum               1.373269e-03
# minor_salivary_gland                   4.228621e-04
# whole_blood                            3.320333e-01
# lung                                   4.905714e-08
# pancreas                               4.739023e-06
# cells_ebvtransformed_lymphocytes       4.352944e-07
# small_intestine_terminal_ileum         4.174152e-10
# liver                                  9.316583e-04
# heart_left_ventricle                   5.164202e-01
# brain_nucleus_accumbens_basal_ganglia  3.251833e-05
# brain_substantia_nigra                 9.007222e-04
# brain_hippocampus                      2.253662e-05
# brain_caudate_basal_ganglia            6.797072e-04
# brain_cortex                           8.570472e-02
# brain_cerebellar_hemisphere            3.891439e-05
# bladder                                3.450003e-01
# brain_putamen_basal_ganglia            4.030928e-04
# brain_hypothalamus                     3.117929e-04
# heart_atrial_appendage                 3.095176e-01
# brain_cerebellum                       5.897648e-01
# kidney_cortex                          5.863872e-02
# brain_spinal_cord_cervical_c1          4.002211e-01
# ovary                                  9.387668e-02
# vagina                                 1.729214e-02
# uterus                                 6.207795e-03
# brain_frontal_cortex_ba9               6.734313e-03
# brain_amygdala                         5.764275e-02
# brain_anterior_cingulate_cortex_ba24   1.221116e-02
# testis                                 5.866689e-01

# %%
res_pval_all.sort_values("spearman")
# Out:
#                                                  cm       pearson  \
# cells_cultured_fibroblasts             9.999990e-07  1.188516e-73
# thyroid                                9.999990e-07  4.844271e-53
# prostate                               9.999990e-07  4.637571e-23
# nerve_tibial                           9.999990e-07  6.073870e-75
# artery_tibial                          9.999990e-07  5.248493e-71
# colon_transverse                       9.999990e-07  1.613504e-16
# esophagus_mucosa                       9.999990e-07  6.374962e-27
# stomach                                9.999990e-07  1.045907e-12
# artery_aorta                           9.999990e-07  4.513966e-40
# esophagus_muscularis                   9.999990e-07  8.650204e-33
# adipose_subcutaneous                   9.999990e-07  6.287645e-40
# colon_sigmoid                          9.999990e-07  2.450898e-28
# skin_sun_exposed_lower_leg             9.999990e-07  5.836576e-27
# adrenal_gland                          9.999990e-07  6.058615e-17
# artery_coronary                        9.999990e-07  9.731623e-16
# breast_mammary_tissue                  9.999990e-07  1.971106e-23
# skin_not_sun_exposed_suprapubic        9.999990e-07  4.784340e-21
# small_intestine_terminal_ileum         9.999990e-07  3.700708e-07
# spleen                                 9.999990e-07  3.291874e-14
# lung                                   9.999990e-07  7.462864e-10
# muscle_skeletal                        9.999990e-07  3.656202e-13
# esophagus_gastroesophageal_junction    9.999990e-07  3.706506e-18
# cells_ebvtransformed_lymphocytes       9.999990e-07  1.706982e-08
# pituitary                              9.999990e-07  2.635795e-22
# pancreas                               9.999990e-07  1.432674e-08
# brain_hippocampus                      9.999990e-07  6.596327e-03
# brain_nucleus_accumbens_basal_ganglia  9.999990e-07  2.567349e-04
# brain_cerebellar_hemisphere            9.999990e-07  1.277016e-02
# brain_hypothalamus                     9.999990e-07  9.332407e-02
# brain_putamen_basal_ganglia            9.999990e-07  7.602316e-02
# minor_salivary_gland                   9.999990e-07  2.601462e-11
# brain_caudate_basal_ganglia            9.999990e-07  7.044831e-03
# brain_substantia_nigra                 9.999990e-07  6.662844e-04
# liver                                  9.999990e-07  3.015460e-06
# adipose_visceral_omentum               9.999990e-07  6.191569e-12
# uterus                                 2.868027e-01  3.532197e-01
# brain_frontal_cortex_ba9               9.999990e-07  4.371643e-01
# brain_anterior_cingulate_cortex_ba24   9.999990e-07  6.460824e-01
# vagina                                 5.256995e-01  3.184237e-01
# brain_amygdala                         9.999990e-07  6.356755e-01
# kidney_cortex                          2.999997e-06  1.157355e-01
# brain_cortex                           9.999990e-07  1.230662e-02
# ovary                                  4.256326e-01  1.793916e-01
# heart_atrial_appendage                 9.999990e-07  9.508466e-02
# whole_blood                            9.999990e-07  3.875814e-11
# bladder                                5.584744e-01  4.577874e-02
# brain_spinal_cord_cervical_c1          9.999990e-07  1.342873e-01
# heart_left_ventricle                   9.999990e-07  6.215317e-05
# testis                                 6.282804e-01  7.366585e-01
# brain_cerebellum                       9.999990e-07  9.916004e-02
#
#                                            spearman
# cells_cultured_fibroblasts             3.662235e-49
# thyroid                                1.541651e-30
# prostate                               8.471438e-27
# nerve_tibial                           1.130228e-25
# artery_tibial                          3.246061e-25
# colon_transverse                       2.880714e-23
# esophagus_mucosa                       2.030847e-21
# stomach                                1.240450e-19
# artery_aorta                           6.380372e-19
# esophagus_muscularis                   8.375537e-18
# adipose_subcutaneous                   2.618709e-17
# colon_sigmoid                          6.395478e-17
# skin_sun_exposed_lower_leg             2.245602e-16
# adrenal_gland                          2.230048e-12
# artery_coronary                        5.220895e-12
# breast_mammary_tissue                  1.756788e-11
# skin_not_sun_exposed_suprapubic        3.167647e-11
# small_intestine_terminal_ileum         4.174152e-10
# spleen                                 8.614195e-10
# lung                                   4.905714e-08
# muscle_skeletal                        1.563020e-07
# esophagus_gastroesophageal_junction    1.604572e-07
# cells_ebvtransformed_lymphocytes       4.352944e-07
# pituitary                              7.465807e-07
# pancreas                               4.739023e-06
# brain_hippocampus                      2.253662e-05
# brain_nucleus_accumbens_basal_ganglia  3.251833e-05
# brain_cerebellar_hemisphere            3.891439e-05
# brain_hypothalamus                     3.117929e-04
# brain_putamen_basal_ganglia            4.030928e-04
# minor_salivary_gland                   4.228621e-04
# brain_caudate_basal_ganglia            6.797072e-04
# brain_substantia_nigra                 9.007222e-04
# liver                                  9.316583e-04
# adipose_visceral_omentum               1.373269e-03
# uterus                                 6.207795e-03
# brain_frontal_cortex_ba9               6.734313e-03
# brain_anterior_cingulate_cortex_ba24   1.221116e-02
# vagina                                 1.729214e-02
# brain_amygdala                         5.764275e-02
# kidney_cortex                          5.863872e-02
# brain_cortex                           8.570472e-02
# ovary                                  9.387668e-02
# heart_atrial_appendage                 3.095176e-01
# whole_blood                            3.320333e-01
# bladder                                3.450003e-01
# brain_spinal_cord_cervical_c1          4.002211e-01
# heart_left_ventricle                   5.164202e-01
# testis                                 5.866689e-01
# brain_cerebellum                       5.897648e-01

# %% [markdown]
# # Save

# %% [markdown]
# ## Coefficient values

# %%
res_all.to_pickle(OUTPUT_DIR / "coef_values.pkl")

# %% [markdown]
# ## Coefficient p-values

# %%
res_pval_all.to_pickle(OUTPUT_DIR / "coef_pvalues.pkl")
