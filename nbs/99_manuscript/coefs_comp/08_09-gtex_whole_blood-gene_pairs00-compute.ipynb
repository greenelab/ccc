# %% [markdown]
# # Description

# %% [markdown]
# It selects one gene pair (see `Settings` below) and computes the correlation coefficients and p-values across all the tissues in GTEx.
# We do this to check whether one pattern found in whole blood also replicates in other tissues.

# %% [markdown]
# # Modules

# %%
import pandas as pd

from scipy.stats import pearsonr, spearmanr
import matplotlib.pyplot as plt
import seaborn as sns

from ccc import conf
from ccc.coef import ccc

# %% [markdown]
# # Settings

# %%
# this gene pair was originally found with ccc on whole blood
# interesting: https://clincancerres.aacrjournals.org/content/26/21/5567.figures-only
gene0_id, gene1_id = "ENSG00000147050.14", "ENSG00000183878.15"
gene0_symbol, gene1_symbol = "KDM6A", "UTY"

CCC_PVALUE_N_PERMS = 1000000

# %% [markdown]
# # Paths

# %%
TISSUE_DIR = conf.GTEX["DATA_DIR"] / "data_by_tissue"
assert TISSUE_DIR.exists()

# %%
OUTPUT_DIR = (
    conf.GTEX["RESULTS_DIR"]
    / "other_tissues"
    / f"{gene0_symbol.lower()}_vs_{gene1_symbol.lower()}"
)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
display(OUTPUT_DIR)
# Out:
# PosixPath('/opt/data/results/gtex_v8/other_tissues/kdm6a_vs_uty')

# %% [markdown]
# # Data

# %% [markdown]
# ## GTEx metadata

# %%
gtex_metadata = pd.read_pickle(conf.GTEX["DATA_DIR"] / "gtex_v8-sample_metadata.pkl")

# %%
gtex_metadata.shape
# Out:
# (22951, 66)

# %%
gtex_metadata.head()
# Out:
#                                    SUBJID     SEX    AGE  DTHHRDY  SMATSSCR  \
# SAMPID
# GTEX-1117F-0003-SM-58Q7G       GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0003-SM-5DWSB       GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0003-SM-6WBT7       GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F  GTEX-1117F  Female  60-69      4.0       NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8  GTEX-1117F  Female  60-69      4.0       NaN
#
#                               SMCENTER SMPTHNTS  SMRIN   SMTS  \
# SAMPID
# GTEX-1117F-0003-SM-58Q7G            B1      NaN    NaN  Blood
# GTEX-1117F-0003-SM-5DWSB            B1      NaN    NaN  Blood
# GTEX-1117F-0003-SM-6WBT7            B1      NaN    NaN  Blood
# GTEX-1117F-0011-R10a-SM-AHZ7F   B1, A1      NaN    NaN  Brain
# GTEX-1117F-0011-R10b-SM-CYKQ8   B1, A1      NaN    7.2  Brain
#
#                                                       SMTSD  ... SME1ANTI  \
# SAMPID                                                       ...
# GTEX-1117F-0003-SM-58Q7G                        Whole Blood  ...      NaN
# GTEX-1117F-0003-SM-5DWSB                        Whole Blood  ...      NaN
# GTEX-1117F-0003-SM-6WBT7                        Whole Blood  ...      NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F  Brain - Frontal Cortex (BA9)  ...      NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8  Brain - Frontal Cortex (BA9)  ...      NaN
#
#                                SMSPLTRD  SMBSMMRT SME1SNSE SME1PCTS SMRRNART  \
# SAMPID
# GTEX-1117F-0003-SM-58Q7G            NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-5DWSB            NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-6WBT7            NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F       NaN       NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8       NaN       NaN      NaN      NaN      NaN
#
#                               SME1MPRT SMNUM5CD SMDPMPRT SME2PCTS
# SAMPID
# GTEX-1117F-0003-SM-58Q7G           NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-5DWSB           NaN      NaN      NaN      NaN
# GTEX-1117F-0003-SM-6WBT7           NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10a-SM-AHZ7F      NaN      NaN      NaN      NaN
# GTEX-1117F-0011-R10b-SM-CYKQ8      NaN      NaN      NaN      NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# ## Gene Ensembl ID -> Symbol mapping

# %%
gene_map = pd.read_pickle(conf.GTEX["DATA_DIR"] / "gtex_gene_id_symbol_mappings.pkl")

# %%
gene_map = gene_map.set_index("gene_ens_id")["gene_symbol"].to_dict()

# %%
assert gene_map["ENSG00000145309.5"] == "CABS1"

# %%
assert gene_map[gene0_id] == gene0_symbol
assert gene_map[gene1_id] == gene1_symbol

# %% [markdown]
# # Compute correlation on all tissues

# %%
res_all = pd.DataFrame(
    {
        f.stem.split("_data_")[1]: {
            "cm": ccc(data[gene0_id], data[gene1_id]),
            "pearson": pearsonr(data[gene0_id], data[gene1_id])[0],
            "spearman": spearmanr(data[gene0_id], data[gene1_id])[0],
        }
        for f in TISSUE_DIR.glob("*.pkl")
        if (data := pd.read_pickle(f).T[[gene0_id, gene1_id]].dropna()) is not None
        and data.shape[0] > 10
    }
).T.abs()

# %%
res_all.shape
# Out:
# (50, 3)

# %%
res_all.head()
# Out:
#                         cm   pearson  spearman
# colon_transverse  0.336727  0.517899  0.408343
# brain_amygdala    0.280524  0.037541  0.147571
# artery_coronary   0.274554  0.413862  0.391764
# artery_aorta      0.429771  0.485788  0.363510
# adrenal_gland     0.260197  0.459190  0.354190

# %%
res_all.sort_values("cm")
# Out:
#                                              cm   pearson  spearman
# uterus                                 0.000000  0.016338  0.041994
# ovary                                  0.006722  0.104096  0.013011
# vagina                                 0.013525  0.074307  0.086761
# brain_cerebellum                       0.187717  0.124874  0.036402
# small_intestine_terminal_ileum         0.193668  0.359150  0.327394
# brain_spinal_cord_cervical_c1          0.198741  0.243850  0.125183
# testis                                 0.206704  0.692661  0.690990
# stomach                                0.209703  0.437367  0.346836
# brain_cortex                           0.219900  0.162729  0.144386
# brain_anterior_cingulate_cortex_ba24   0.231620  0.002993  0.182207
# pituitary                              0.235652  0.526137  0.229717
# brain_cerebellar_hemisphere            0.237310  0.147620  0.259815
# brain_hippocampus                      0.241846  0.239342  0.301170
# heart_atrial_appendage                 0.246321  0.095973  0.039109
# adrenal_gland                          0.260197  0.459190  0.354190
# liver                                  0.265571  0.467397  0.309052
# brain_frontal_cortex_ba9               0.265633  0.051099  0.188904
# muscle_skeletal                        0.270261  0.248322  0.215619
# artery_coronary                        0.274554  0.413862  0.391764
# pancreas                               0.278667  0.286178  0.196846
# adipose_visceral_omentum               0.280211  0.198846  0.053794
# brain_amygdala                         0.280524  0.037541  0.147571
# stomach                                0.209703  0.437367  0.346836
# adrenal_gland                          0.260197  0.459190  0.354190
# artery_aorta                           0.429771  0.485788  0.363510
# colon_sigmoid                          0.426371  0.547466  0.365301
# cells_cultured_fibroblasts             0.470435  0.530970  0.369543
# thyroid                                0.407921  0.588574  0.378012
# artery_coronary                        0.274554  0.413862  0.391764
# colon_transverse                       0.336727  0.517899  0.408343
# testis                                 0.206704  0.692661  0.690990
# prostate                               0.347597  0.804046  0.799923

# %% [markdown]
# # Compute p-values on all tissues

# %%
res_pval_all = pd.DataFrame(
    {
        f.stem.split("_data_")[1]: {
            "cm": ccc(
                data[gene0_id],
                data[gene1_id],
                pvalue_n_perms=CCC_PVALUE_N_PERMS,
                n_jobs=conf.GENERAL["N_JOBS"],
            )[1],
            "pearson": pearsonr(data[gene0_id], data[gene1_id])[1],
            "spearman": spearmanr(data[gene0_id], data[gene1_id])[1],
        }
        for f in TISSUE_DIR.glob("*.pkl")
        if (data := pd.read_pickle(f).T[[gene0_id, gene1_id]].dropna()) is not None
        and data.shape[0] > 10
    }
).T.abs()

# %%
res_pval_all.shape
# Out:
# (50, 3)

# %%
res_pval_all.head()
# Out:
#                             cm       pearson      spearman
# colon_transverse  9.999990e-07  3.063714e-29  9.539164e-18
# brain_amygdala    9.999990e-07  6.461089e-01  6.963023e-02
# artery_coronary   9.999990e-07  2.389970e-11  3.159321e-10
# artery_aorta      9.999990e-07  5.775754e-27  6.092383e-15
# adrenal_gland     9.999990e-07  7.334489e-15  4.847677e-09

# %%
res_pval_all.sort_values("cm")
# Out:
#                                                  cm       pearson  \
# colon_transverse                       9.999990e-07  3.063714e-29
# brain_frontal_cortex_ba9               9.999990e-07  4.624712e-01
# brain_caudate_basal_ganglia            9.999990e-07  6.385581e-02
# testis                                 9.999990e-07  6.885883e-53
# muscle_skeletal                        9.999990e-07  9.476952e-13
# stomach                                9.999990e-07  3.314971e-18
# skin_not_sun_exposed_suprapubic        9.999990e-07  1.328216e-14
# adipose_visceral_omentum               9.999990e-07  3.147140e-06
# nerve_tibial                           9.999990e-07  1.544394e-64
# pancreas                               9.999990e-07  1.336164e-07
# breast_mammary_tissue                  9.999990e-07  6.601903e-17
# spleen                                 9.999990e-07  3.528031e-16
# brain_nucleus_accumbens_basal_ganglia  9.999990e-07  7.405960e-05
# minor_salivary_gland                   9.999990e-07  3.438268e-13
# kidney_cortex                          9.999990e-07  8.678213e-02
# esophagus_muscularis                   9.999990e-07  4.264868e-36
# thyroid                                9.999990e-07  4.016259e-62
# small_intestine_terminal_ileum         9.999990e-07  4.468977e-07
# cells_cultured_fibroblasts             9.999990e-07  5.273450e-38
# artery_tibial                          9.999990e-07  2.616759e-53
# brain_hypothalamus                     9.999990e-07  4.892671e-02
# lung                                   9.999990e-07  2.942043e-21
# prostate                               9.999990e-07  8.574051e-57
# brain_cerebellum                       9.999990e-07  5.285837e-02
# brain_spinal_cord_cervical_c1          9.999990e-07  1.951845e-03
# brain_putamen_basal_ganglia            9.999990e-07  1.682309e-02
# brain_amygdala                         9.999990e-07  6.461089e-01
# artery_coronary                        9.999990e-07  2.389970e-11
# artery_aorta                           9.999990e-07  5.775754e-27
# adrenal_gland                          9.999990e-07  7.334489e-15
# brain_substantia_nigra                 9.999990e-07  1.120610e-03
# brain_cortex                           9.999990e-07  9.236109e-03
# brain_anterior_cingulate_cortex_ba24   9.999990e-07  9.685512e-01
# brain_cerebellar_hemisphere            9.999990e-07  3.048099e-02
# heart_left_ventricle                   9.999990e-07  1.249740e-04
# esophagus_mucosa                       9.999990e-07  1.532117e-25
# brain_hippocampus                      9.999990e-07  7.058026e-04
# esophagus_gastroesophageal_junction    9.999990e-07  7.650213e-19
# liver                                  9.999990e-07  1.149699e-13
# skin_sun_exposed_lower_leg             9.999990e-07  3.753789e-21
# heart_atrial_appendage                 9.999990e-07  4.696447e-02
# whole_blood                            9.999990e-07  2.425885e-11
# adipose_subcutaneous                   9.999990e-07  3.380047e-37
# cells_ebvtransformed_lymphocytes       9.999990e-07  7.017453e-14
# pituitary                              9.999990e-07  1.500644e-21
# colon_sigmoid                          9.999990e-07  1.492599e-30
# bladder                                1.711398e-02  7.901570e-01
# vagina                                 6.331194e-01  3.565768e-01
# ovary                                  8.434682e-01  1.643316e-01
# uterus                                 1.000000e+00  8.469705e-01
#
#                                            spearman
# colon_transverse                       9.539164e-18
# brain_frontal_cortex_ba9               6.157446e-03
# brain_caudate_basal_ganglia            1.644387e-03
# testis                                 1.530166e-52
# muscle_skeletal                        6.688791e-10
# stomach                                1.383202e-11
# skin_not_sun_exposed_suprapubic        1.756507e-04
# adipose_visceral_omentum               2.115860e-01
# nerve_tibial                           6.654551e-19
# pancreas                               3.350402e-04
# breast_mammary_tissue                  3.732022e-08
# spleen                                 1.905368e-07
# brain_nucleus_accumbens_basal_ganglia  4.543876e-05
# minor_salivary_gland                   1.203253e-02
# kidney_cortex                          2.879591e-02
# esophagus_muscularis                   5.670023e-15
# thyroid                                1.307527e-23
# small_intestine_terminal_ileum         4.791725e-06
# cells_cultured_fibroblasts             9.384953e-18
# artery_tibial                          2.412324e-16
# brain_hypothalamus                     9.024640e-05
# lung                                   2.613595e-07
# prostate                               8.192150e-56
# brain_cerebellum                       5.738722e-01
# brain_spinal_cord_cervical_c1          1.158973e-01
# brain_putamen_basal_ganglia            1.755768e-04
# brain_amygdala                         6.963023e-02
# artery_coronary                        3.159321e-10
# artery_aorta                           6.092383e-15
# adrenal_gland                          4.847677e-09
# brain_substantia_nigra                 5.370512e-04
# brain_cortex                           2.108691e-02
# brain_anterior_cingulate_cortex_ba24   1.550692e-02
# brain_cerebellar_hemisphere            1.162872e-04
# heart_left_ventricle                   9.005479e-01
# esophagus_mucosa                       2.415653e-11
# brain_hippocampus                      1.704150e-05
# esophagus_gastroesophageal_junction    5.231960e-06
# liver                                  2.171397e-06
# skin_sun_exposed_lower_leg             4.082187e-06
# heart_atrial_appendage                 4.190979e-01
# whole_blood                            5.653224e-03
# adipose_subcutaneous                   1.605395e-12
# cells_ebvtransformed_lymphocytes       1.131094e-05
# pituitary                              9.635109e-05
# colon_sigmoid                          3.222739e-13
# bladder                                9.242248e-01
# vagina                                 2.814964e-01
# ovary                                  8.623791e-01
# uterus                                 6.197471e-01

# %%
res_pval_all.sort_values("pearson")
# Out:
#                                                  cm       pearson  \
# nerve_tibial                           9.999990e-07  1.544394e-64
# thyroid                                9.999990e-07  4.016259e-62
# prostate                               9.999990e-07  8.574051e-57
# artery_tibial                          9.999990e-07  2.616759e-53
# testis                                 9.999990e-07  6.885883e-53
# cells_cultured_fibroblasts             9.999990e-07  5.273450e-38
# adipose_subcutaneous                   9.999990e-07  3.380047e-37
# esophagus_muscularis                   9.999990e-07  4.264868e-36
# colon_sigmoid                          9.999990e-07  1.492599e-30
# colon_transverse                       9.999990e-07  3.063714e-29
# artery_aorta                           9.999990e-07  5.775754e-27
# esophagus_mucosa                       9.999990e-07  1.532117e-25
# pituitary                              9.999990e-07  1.500644e-21
# lung                                   9.999990e-07  2.942043e-21
# skin_sun_exposed_lower_leg             9.999990e-07  3.753789e-21
# esophagus_gastroesophageal_junction    9.999990e-07  7.650213e-19
# stomach                                9.999990e-07  3.314971e-18
# breast_mammary_tissue                  9.999990e-07  6.601903e-17
# spleen                                 9.999990e-07  3.528031e-16
# adrenal_gland                          9.999990e-07  7.334489e-15
# skin_not_sun_exposed_suprapubic        9.999990e-07  1.328216e-14
# cells_ebvtransformed_lymphocytes       9.999990e-07  7.017453e-14
# liver                                  9.999990e-07  1.149699e-13
# minor_salivary_gland                   9.999990e-07  3.438268e-13
# muscle_skeletal                        9.999990e-07  9.476952e-13
# artery_coronary                        9.999990e-07  2.389970e-11
# whole_blood                            9.999990e-07  2.425885e-11
# pancreas                               9.999990e-07  1.336164e-07
# small_intestine_terminal_ileum         9.999990e-07  4.468977e-07
# adipose_visceral_omentum               9.999990e-07  3.147140e-06
# brain_nucleus_accumbens_basal_ganglia  9.999990e-07  7.405960e-05
# heart_left_ventricle                   9.999990e-07  1.249740e-04
# brain_hippocampus                      9.999990e-07  7.058026e-04
# brain_substantia_nigra                 9.999990e-07  1.120610e-03
# brain_spinal_cord_cervical_c1          9.999990e-07  1.951845e-03
# brain_cortex                           9.999990e-07  9.236109e-03
# brain_putamen_basal_ganglia            9.999990e-07  1.682309e-02
# brain_cerebellar_hemisphere            9.999990e-07  3.048099e-02
# heart_atrial_appendage                 9.999990e-07  4.696447e-02
# brain_hypothalamus                     9.999990e-07  4.892671e-02
# brain_cerebellum                       9.999990e-07  5.285837e-02
# brain_caudate_basal_ganglia            9.999990e-07  6.385581e-02
# kidney_cortex                          9.999990e-07  8.678213e-02
# ovary                                  8.434682e-01  1.643316e-01
# vagina                                 6.331194e-01  3.565768e-01
# brain_frontal_cortex_ba9               9.999990e-07  4.624712e-01
# brain_amygdala                         9.999990e-07  6.461089e-01
# bladder                                1.711398e-02  7.901570e-01
# uterus                                 1.000000e+00  8.469705e-01
# brain_anterior_cingulate_cortex_ba24   9.999990e-07  9.685512e-01
#
#                                            spearman
# nerve_tibial                           6.654551e-19
# thyroid                                1.307527e-23
# prostate                               8.192150e-56
# artery_tibial                          2.412324e-16
# testis                                 1.530166e-52
# cells_cultured_fibroblasts             9.384953e-18
# adipose_subcutaneous                   1.605395e-12
# esophagus_muscularis                   5.670023e-15
# colon_sigmoid                          3.222739e-13
# colon_transverse                       9.539164e-18
# artery_aorta                           6.092383e-15
# esophagus_mucosa                       2.415653e-11
# pituitary                              9.635109e-05
# lung                                   2.613595e-07
# skin_sun_exposed_lower_leg             4.082187e-06
# esophagus_gastroesophageal_junction    5.231960e-06
# stomach                                1.383202e-11
# breast_mammary_tissue                  3.732022e-08
# spleen                                 1.905368e-07
# adrenal_gland                          4.847677e-09
# skin_not_sun_exposed_suprapubic        1.756507e-04
# cells_ebvtransformed_lymphocytes       1.131094e-05
# liver                                  2.171397e-06
# minor_salivary_gland                   1.203253e-02
# muscle_skeletal                        6.688791e-10
# artery_coronary                        3.159321e-10
# whole_blood                            5.653224e-03
# pancreas                               3.350402e-04
# small_intestine_terminal_ileum         4.791725e-06
# adipose_visceral_omentum               2.115860e-01
# brain_nucleus_accumbens_basal_ganglia  4.543876e-05
# heart_left_ventricle                   9.005479e-01
# brain_hippocampus                      1.704150e-05
# brain_substantia_nigra                 5.370512e-04
# brain_spinal_cord_cervical_c1          1.158973e-01
# brain_cortex                           2.108691e-02
# brain_putamen_basal_ganglia            1.755768e-04
# brain_cerebellar_hemisphere            1.162872e-04
# heart_atrial_appendage                 4.190979e-01
# brain_hypothalamus                     9.024640e-05
# brain_cerebellum                       5.738722e-01
# brain_caudate_basal_ganglia            1.644387e-03
# kidney_cortex                          2.879591e-02
# ovary                                  8.623791e-01
# vagina                                 2.814964e-01
# brain_frontal_cortex_ba9               6.157446e-03
# brain_amygdala                         6.963023e-02
# bladder                                9.242248e-01
# uterus                                 6.197471e-01
# brain_anterior_cingulate_cortex_ba24   1.550692e-02

# %%
res_pval_all.sort_values("spearman")
# Out:
#                                                  cm       pearson  \
# prostate                               9.999990e-07  8.574051e-57
# testis                                 9.999990e-07  6.885883e-53
# thyroid                                9.999990e-07  4.016259e-62
# nerve_tibial                           9.999990e-07  1.544394e-64
# cells_cultured_fibroblasts             9.999990e-07  5.273450e-38
# colon_transverse                       9.999990e-07  3.063714e-29
# artery_tibial                          9.999990e-07  2.616759e-53
# esophagus_muscularis                   9.999990e-07  4.264868e-36
# artery_aorta                           9.999990e-07  5.775754e-27
# colon_sigmoid                          9.999990e-07  1.492599e-30
# adipose_subcutaneous                   9.999990e-07  3.380047e-37
# stomach                                9.999990e-07  3.314971e-18
# esophagus_mucosa                       9.999990e-07  1.532117e-25
# artery_coronary                        9.999990e-07  2.389970e-11
# muscle_skeletal                        9.999990e-07  9.476952e-13
# adrenal_gland                          9.999990e-07  7.334489e-15
# breast_mammary_tissue                  9.999990e-07  6.601903e-17
# spleen                                 9.999990e-07  3.528031e-16
# lung                                   9.999990e-07  2.942043e-21
# liver                                  9.999990e-07  1.149699e-13
# skin_sun_exposed_lower_leg             9.999990e-07  3.753789e-21
# small_intestine_terminal_ileum         9.999990e-07  4.468977e-07
# esophagus_gastroesophageal_junction    9.999990e-07  7.650213e-19
# cells_ebvtransformed_lymphocytes       9.999990e-07  7.017453e-14
# brain_hippocampus                      9.999990e-07  7.058026e-04
# brain_nucleus_accumbens_basal_ganglia  9.999990e-07  7.405960e-05
# brain_hypothalamus                     9.999990e-07  4.892671e-02
# pituitary                              9.999990e-07  1.500644e-21
# brain_cerebellar_hemisphere            9.999990e-07  3.048099e-02
# brain_putamen_basal_ganglia            9.999990e-07  1.682309e-02
# skin_not_sun_exposed_suprapubic        9.999990e-07  1.328216e-14
# pancreas                               9.999990e-07  1.336164e-07
# brain_substantia_nigra                 9.999990e-07  1.120610e-03
# brain_caudate_basal_ganglia            9.999990e-07  6.385581e-02
# whole_blood                            9.999990e-07  2.425885e-11
# brain_frontal_cortex_ba9               9.999990e-07  4.624712e-01
# minor_salivary_gland                   9.999990e-07  3.438268e-13
# brain_anterior_cingulate_cortex_ba24   9.999990e-07  9.685512e-01
# brain_cortex                           9.999990e-07  9.236109e-03
# kidney_cortex                          9.999990e-07  8.678213e-02
# brain_amygdala                         9.999990e-07  6.461089e-01
# brain_spinal_cord_cervical_c1          9.999990e-07  1.951845e-03
# adipose_visceral_omentum               9.999990e-07  3.147140e-06
# vagina                                 6.331194e-01  3.565768e-01
# heart_atrial_appendage                 9.999990e-07  4.696447e-02
# brain_cerebellum                       9.999990e-07  5.285837e-02
# uterus                                 1.000000e+00  8.469705e-01
# ovary                                  8.434682e-01  1.643316e-01
# heart_left_ventricle                   9.999990e-07  1.249740e-04
# bladder                                1.711398e-02  7.901570e-01
#
#                                            spearman
# prostate                               8.192150e-56
# testis                                 1.530166e-52
# thyroid                                1.307527e-23
# nerve_tibial                           6.654551e-19
# cells_cultured_fibroblasts             9.384953e-18
# colon_transverse                       9.539164e-18
# artery_tibial                          2.412324e-16
# esophagus_muscularis                   5.670023e-15
# artery_aorta                           6.092383e-15
# colon_sigmoid                          3.222739e-13
# adipose_subcutaneous                   1.605395e-12
# stomach                                1.383202e-11
# esophagus_mucosa                       2.415653e-11
# artery_coronary                        3.159321e-10
# muscle_skeletal                        6.688791e-10
# adrenal_gland                          4.847677e-09
# breast_mammary_tissue                  3.732022e-08
# spleen                                 1.905368e-07
# lung                                   2.613595e-07
# liver                                  2.171397e-06
# skin_sun_exposed_lower_leg             4.082187e-06
# small_intestine_terminal_ileum         4.791725e-06
# esophagus_gastroesophageal_junction    5.231960e-06
# cells_ebvtransformed_lymphocytes       1.131094e-05
# brain_hippocampus                      1.704150e-05
# brain_nucleus_accumbens_basal_ganglia  4.543876e-05
# brain_hypothalamus                     9.024640e-05
# pituitary                              9.635109e-05
# brain_cerebellar_hemisphere            1.162872e-04
# brain_putamen_basal_ganglia            1.755768e-04
# skin_not_sun_exposed_suprapubic        1.756507e-04
# pancreas                               3.350402e-04
# brain_substantia_nigra                 5.370512e-04
# brain_caudate_basal_ganglia            1.644387e-03
# whole_blood                            5.653224e-03
# brain_frontal_cortex_ba9               6.157446e-03
# minor_salivary_gland                   1.203253e-02
# brain_anterior_cingulate_cortex_ba24   1.550692e-02
# brain_cortex                           2.108691e-02
# kidney_cortex                          2.879591e-02
# brain_amygdala                         6.963023e-02
# brain_spinal_cord_cervical_c1          1.158973e-01
# adipose_visceral_omentum               2.115860e-01
# vagina                                 2.814964e-01
# heart_atrial_appendage                 4.190979e-01
# brain_cerebellum                       5.738722e-01
# uterus                                 6.197471e-01
# ovary                                  8.623791e-01
# heart_left_ventricle                   9.005479e-01
# bladder                                9.242248e-01

# %% [markdown]
# # Save

# %% [markdown]
# ## Coefficient values

# %%
res_all.to_pickle(OUTPUT_DIR / "coef_values.pkl")

# %% [markdown]
# ## Coefficient p-values

# %%
res_pval_all.to_pickle(OUTPUT_DIR / "coef_pvalues.pkl")
