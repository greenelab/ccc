# %% [markdown]
# # Description

# %% [markdown]
# This notebook contains code taken from the MultiPLIER repo to download and process recount2 data.
# The code was taken from [here](https://github.com/greenelab/rheum-plier-data/blob/master/recount2/1-get_all_recount_dataset.R) and [here](https://github.com/greenelab/rheum-plier-data/blob/master/recount2/2-prep_recount_for_plier.R).
#
# The output are Python pickle files with a large matrix with genes in rows and samples in columns, and another file with gene ID mappings.

# %% [markdown]
# # Modules

# %%
`%>%` <- dplyr::`%>%`
library(recount)
# Out:
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
# Setting options('download.file.method.GEOquery'='auto')
#
# Setting options('GEOquery.inmemory.gpl'=FALSE)

# %% [markdown]
# # Settings

# %%
recount2full.data.dir <- Sys.getenv("CM_RECOUNT2FULL_DATA_DIR")

# %%
recount2full.data.dir
# Out:
# [1] "/opt/data/data/recount2full"

# %%
dir.create(recount2full.data.dir, recursive = TRUE, showWarnings = FALSE)

# %%
data.dir <- Sys.getenv("CM_RECOUNT2FULL_INTERNAL_DATA_DIR")

# %%
data.dir
# Out:
# [1] "/opt/data/data/recount2full/data"

# %%
dir.create(data.dir, recursive = TRUE, showWarnings = FALSE)

# %% [markdown]
# # Functions

# %%
# Get RPKM value for each gene - adapted from recount package
getRPKM <- function(rse, length_var = "bp_length", mapped_var = NULL) {
  # Computes the RPKM value for each gene in the sample.
  #
  # Args:
  #  rse: A RangedSummarizedExperiment-class object in recount package
  #  length_var: A length 1 character vector with the column name from rowData(rse) that has
  #              the coding length. For gene level objects from recount this is bp_length. If
  #              NULL, then it will use width(rowRanges(rse)) which should be used for exon RSEs.
  #  mapped_var: A length 1 character vector with the column name from colData(rse) that has
  #              the number of reads mapped. If NULL (default) then it will use the column
  #              sums of the counts matrix
  # Returns:
  #   RPKM value for each sample
  if (!is.null(mapped_var)) {
    mapped <- colData(rse)[, mapped_var]
  } else {
    mapped <- colSums(assays(rse)$counts)
  }
  bg <- matrix(mapped, ncol = ncol(rse), nrow = nrow(rse), byrow = TRUE)
  if (!is.null(length_var)) {
    len <- rowData(rse)[, length_var]
  } else {
    len <- width(rowRanges(rse))
  }
  wid <- matrix(len, nrow = nrow(rse), ncol = ncol(rse), byrow = FALSE)
  rpkm <- assays(rse)$counts / (wid / 1000) / (bg / 1e6)
  return(rpkm)
}

# %% [markdown]
# # Download

# %%
# Get all samples from recount database
metasample.sra <- all_metadata(subset = "sra", verbose = TRUE)
metasample.sra <- as.data.frame(metasample.sra)
# Out:
# 2021-12-24 02:47:51 downloading the metadata to /tmp/RtmpPx1lPX/metadata_clean_sra.Rdata

# %%
# Remove samples without description
metadata.nonempty <- metasample.sra[!is.na(metasample.sra$characteristics), ]
included.sample.list <- unique(metadata.nonempty$project)

# %%
# Download all recount2 samples in included.sample.list
lapply(
  included.sample.list,
  function(x) {
    download_study(x,
      type = "rse-gene",
      outdir = file.path(data.dir, x)
    )
  }
)
# Out:
# 2021-12-24 02:47:54 downloading file rse_gene.Rdata to /opt/data/data/recount2full/data/SRP000599
#
# 2021-12-24 02:47:57 downloading file rse_gene.Rdata to /opt/data/data/recount2full/data/SRP001313
#
# 2021-12-24 02:47:59 downloading file rse_gene.Rdata to /opt/data/data/recount2full/data/SR
]
# [1] "http://duffel.rail.bio/recount/v2/SRP058783/rse_gene.Rdata"
#
# [[1265]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058804/rse_gene.Rdata"
#
# [[1266]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058822/rse_gene.Rdata"
#
# [[1267]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058840/rse_gene.Rdata"
#
# [[1268]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058841/rse_gene.Rdata"
#
# [[1269]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058856/rse_gene.Rdata"
#
# [[1270]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058977/rse_gene.Rdata"
#
# [[1271]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059035/rse_gene.Rdata"
#
# [[1272]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059039/rse_gene.Rdata"
#
# [[1273]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059057/rse_gene.Rdata"
#
# [[1274]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059066/rse_gene.Rdata"
#
# [[1275]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059170/rse_gene.Rdata"
#
# [[1276]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059172/rse_gene.Rdata"
#
# [[1277]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059197/rse_gene.Rdata"
#
# [[1278]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059205/rse_gene.Rdata"
#
# [[1279]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059242/rse_gene.Rdata"
#
# [[1280]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059266/rse_gene.Rdata"
#
# [[1281]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059275/rse_gene.Rdata"
#
# [[1282]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059279/rse_gene.Rdata"
#
# [[1283]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059379/rse_gene.Rdata"
#
# [[1284]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059431/rse_gene.Rdata"
#
# [[1285]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059509/rse_gene.Rdata"
#
# [[1286]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059531/rse_gene.Rdata"
#
# [[1287]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059643/rse_gene.Rdata"
#
# [[1288]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059692/rse_gene.Rdata"
#
# [[1289]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059695/rse_gene.Rdata"
#
# [[1290]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059701/rse_gene.Rdata"
#
# [[1291]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059732/rse_gene.Rdata"
#
# [[1292]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059733/rse_gene.Rdata"
#
# [[1293]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059735/rse_gene.Rdata"
#
# [[1294]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059775/rse_gene.Rdata"
#
# [[1295]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059925/rse_gene.Rdata"
#
# [[1296]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059948/rse_gene.Rdata"
#
# [[1297]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059950/rse_gene.Rdata"
#
# [[1298]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059957/rse_gene.Rdata"
#
# [[1299]]
# [1] "http://duffel.rail.bio/recount/v2/SRP059959/rse_gene.Rdata"
#
# [[1300]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060227/rse_gene.Rdata"
#
# [[1301]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060348/rse_gene.Rdata"
#
# [[1302]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060359/rse_gene.Rdata"
#
# [[1303]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060370/rse_gene.Rdata"
#
# [[1304]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060416/rse_gene.Rdata"
#
# [[1305]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060598/rse_gene.Rdata"
#
# [[1306]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060637/rse_gene.Rdata"
#
# [[1307]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060650/rse_gene.Rdata"
#
# [[1308]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060661/rse_gene.Rdata"
#
# [[1309]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060708/rse_gene.Rdata"
#
# [[1310]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060715/rse_gene.Rdata"
#
# [[1311]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061033/rse_gene.Rdata"
#
# [[1312]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061207/rse_gene.Rdata"
#
# [[1313]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061240/rse_gene.Rdata"
#
# [[1314]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061241/rse_gene.Rdata"
#
# [[1315]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061243/rse_gene.Rdata"
#
# [[1316]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061292/rse_gene.Rdata"
#
# [[1317]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061310/rse_gene.Rdata"
#
# [[1318]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061329/rse_gene.Rdata"
#
# [[1319]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061380/rse_gene.Rdata"
#
# [[1320]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061405/rse_gene.Rdata"
#
# [[1321]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061416/rse_gene.Rdata"
#
# [[1322]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061425/rse_gene.Rdata"
#
# [[1323]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061426/rse_gene.Rdata"
#
# [[1324]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061455/rse_gene.Rdata"
#
# [[1325]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061462/rse_gene.Rdata"
#
# [[1326]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061522/rse_gene.Rdata"
#
# [[1327]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061539/rse_gene.Rdata"
#
# [[1328]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061566/rse_gene.Rdata"
#
# [[1329]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061639/rse_gene.Rdata"
#
# [[1330]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061682/rse_gene.Rdata"
#
# [[1331]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061685/rse_gene.Rdata"
#
# [[1332]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061689/rse_gene.Rdata"
#
# [[1333]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061701/rse_gene.Rdata"
#
# [[1334]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061801/rse_gene.Rdata"
#
# [[1335]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061840/rse_gene.Rdata"
#
# [[1336]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061881/rse_gene.Rdata"
#
# [[1337]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061888/rse_gene.Rdata"
#
# [[1338]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061932/rse_gene.Rdata"
#
# [[1339]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062010/rse_gene.Rdata"
#
# [[1340]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062025/rse_gene.Rdata"
#
# [[1341]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062177/rse_gene.Rdata"
#
# [[1342]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062188/rse_gene.Rdata"
#
# [[1343]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062214/rse_gene.Rdata"
#
# [[1344]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062230/rse_gene.Rdata"
#
# [[1345]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062287/rse_gene.Rdata"
#
# [[1346]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062332/rse_gene.Rdata"
#
# [[1347]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062389/rse_gene.Rdata"
#
# [[1348]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062544/rse_gene.Rdata"
#
# [[1349]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062617/rse_gene.Rdata"
#
# [[1350]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062873/rse_gene.Rdata"
#
# [[1351]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062956/rse_gene.Rdata"
#
# [[1352]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062958/rse_gene.Rdata"
#
# [[1353]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062966/rse_gene.Rdata"
#
# [[1354]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063059/rse_gene.Rdata"
#
# [[1355]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063070/rse_gene.Rdata"
#
# [[1356]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063339/rse_gene.Rdata"
#
# [[1357]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063363/rse_gene.Rdata"
#
# [[1358]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063493/rse_gene.Rdata"
#
# [[1359]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063496/rse_gene.Rdata"
#
# [[1360]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063500/rse_gene.Rdata"
#
# [[1361]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063573/rse_gene.Rdata"
#
# [[1362]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063620/rse_gene.Rdata"
#
# [[1363]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063658/rse_gene.Rdata"
#
# [[1364]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063661/rse_gene.Rdata"
#
# [[1365]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063669/rse_gene.Rdata"
#
# [[1366]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063834/rse_gene.Rdata"
#
# [[1367]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063838/rse_gene.Rdata"
#
# [[1368]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063840/rse_gene.Rdata"
#
# [[1369]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063860/rse_gene.Rdata"
#
# [[1370]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063867/rse_gene.Rdata"
#
# [[1371]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063889/rse_gene.Rdata"
#
# [[1372]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063948/rse_gene.Rdata"
#
# [[1373]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063978/rse_gene.Rdata"
#
# [[1374]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063980/rse_gene.Rdata"
#
# [[1375]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064143/rse_gene.Rdata"
#
# [[1376]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064259/rse_gene.Rdata"
#
# [[1377]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064316/rse_gene.Rdata"
#
# [[1378]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064317/rse_gene.Rdata"
#
# [[1379]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064321/rse_gene.Rdata"
#
# [[1380]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064323/rse_gene.Rdata"
#
# [[1381]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064410/rse_gene.Rdata"
#
# [[1382]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064454/rse_gene.Rdata"
#
# [[1383]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064457/rse_gene.Rdata"
#
# [[1384]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064458/rse_gene.Rdata"
#
# [[1385]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064464/rse_gene.Rdata"
#
# [[1386]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064481/rse_gene.Rdata"
#
# [[1387]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064561/rse_gene.Rdata"
#
# [[1388]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064562/rse_gene.Rdata"
#
# [[1389]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064624/rse_gene.Rdata"
#
# [[1390]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064625/rse_gene.Rdata"
#
# [[1391]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064652/rse_gene.Rdata"
#
# [[1392]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064671/rse_gene.Rdata"
#
# [[1393]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064735/rse_gene.Rdata"
#
# [[1394]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064783/rse_gene.Rdata"
#
# [[1395]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064820/rse_gene.Rdata"
#
# [[1396]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064967/rse_gene.Rdata"
#
# [[1397]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065153/rse_gene.Rdata"
#
# [[1398]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065196/rse_gene.Rdata"
#
# [[1399]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065202/rse_gene.Rdata"
#
# [[1400]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065219/rse_gene.Rdata"
#
# [[1401]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065258/rse_gene.Rdata"
#
# [[1402]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065282/rse_gene.Rdata"
#
# [[1403]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065445/rse_gene.Rdata"
#
# [[1404]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065451/rse_gene.Rdata"
#
# [[1405]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065491/rse_gene.Rdata"
#
# [[1406]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065500/rse_gene.Rdata"
#
# [[1407]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065559/rse_gene.Rdata"
#
# [[1408]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065763/rse_gene.Rdata"
#
# [[1409]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065774/rse_gene.Rdata"
#
# [[1410]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065812/rse_gene.Rdata"
#
# [[1411]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065849/rse_gene.Rdata"
#
# [[1412]]
# [1] "http://duffel.rail.bio/recount/v2/SRP065988/rse_gene.Rdata"
#
# [[1413]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066150/rse_gene.Rdata"
#
# [[1414]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066151/rse_gene.Rdata"
#
# [[1415]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066152/rse_gene.Rdata"
#
# [[1416]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066356/rse_gene.Rdata"
#
# [[1417]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066363/rse_gene.Rdata"
#
# [[1418]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066371/rse_gene.Rdata"
#
# [[1419]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066424/rse_gene.Rdata"
#
# [[1420]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066729/rse_gene.Rdata"
#
# [[1421]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066834/rse_gene.Rdata"
#
# [[1422]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066895/rse_gene.Rdata"
#
# [[1423]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066912/rse_gene.Rdata"
#
# [[1424]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066917/rse_gene.Rdata"
#
# [[1425]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066956/rse_gene.Rdata"
#
# [[1426]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066959/rse_gene.Rdata"
#
# [[1427]]
# [1] "http://duffel.rail.bio/recount/v2/SRP066994/rse_gene.Rdata"
#
# [[1428]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067173/rse_gene.Rdata"
#
# [[1429]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067214/rse_gene.Rdata"
#
# [[1430]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067469/rse_gene.Rdata"
#
# [[1431]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067529/rse_gene.Rdata"
#
# [[1432]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067645/rse_gene.Rdata"
#
# [[1433]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067661/rse_gene.Rdata"
#
# [[1434]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067701/rse_gene.Rdata"
#
# [[1435]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067836/rse_gene.Rdata"
#
# [[1436]]
# [1] "http://duffel.rail.bio/recount/v2/SRP068078/rse_gene.Rdata"
#
# [[1437]]
# [1] "http://duffel.rail.bio/recount/v2/SRP068139/rse_gene.Rdata"
#
# [[1438]]
# [1] "http://duffel.rail.bio/recount/v2/SRP068194/rse_gene.Rdata"
#
# [[1439]]
# [1] "http://duffel.rail.bio/recount/v2/SRP068318/rse_gene.Rdata"
#
# [[1440]]
# [1] "http://duffel.rail.bio/recount/v2/SRP068523/rse_gene.Rdata"
#
# [[1441]]
# [1] "http://duffel.rail.bio/recount/v2/SRP068942/rse_gene.Rdata"
#
# [[1442]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062773/rse_gene.Rdata"
#
# [[1443]]
# [1] "http://duffel.rail.bio/recount/v2/SRP045569/rse_gene.Rdata"
#
# [[1444]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061880/rse_gene.Rdata"
#
# [[1445]]
# [1] "http://duffel.rail.bio/recount/v2/SRP061397/rse_gene.Rdata"
#
# [[1446]]
# [1] "http://duffel.rail.bio/recount/v2/SRP067934/rse_gene.Rdata"
#
# [[1447]]
# [1] "http://duffel.rail.bio/recount/v2/SRP050551/rse_gene.Rdata"
#
# [[1448]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058626/rse_gene.Rdata"
#
# [[1449]]
# [1] "http://duffel.rail.bio/recount/v2/SRP044271/rse_gene.Rdata"
#
# [[1450]]
# [1] "http://duffel.rail.bio/recount/v2/SRP040998/rse_gene.Rdata"
#
# [[1451]]
# [1] "http://duffel.rail.bio/recount/v2/SRP049462/rse_gene.Rdata"
#
# [[1452]]
# [1] "http://duffel.rail.bio/recount/v2/SRP060355/rse_gene.Rdata"
#
# [[1453]]
# [1] "http://duffel.rail.bio/recount/v2/SRP056498/rse_gene.Rdata"
#
# [[1454]]
# [1] "http://duffel.rail.bio/recount/v2/SRP048683/rse_gene.Rdata"
#
# [[1455]]
# [1] "http://duffel.rail.bio/recount/v2/SRP050089/rse_gene.Rdata"
#
# [[1456]]
# [1] "http://duffel.rail.bio/recount/v2/SRP042184/rse_gene.Rdata"
#
# [[1457]]
# [1] "http://duffel.rail.bio/recount/v2/SRP063477/rse_gene.Rdata"
#
# [[1458]]
# [1] "http://duffel.rail.bio/recount/v2/SRP036848/rse_gene.Rdata"
#
# [[1459]]
# [1] "http://duffel.rail.bio/recount/v2/SRP039909/rse_gene.Rdata"
#
# [[1460]]
# [1] "http://duffel.rail.bio/recount/v2/SRP058722/rse_gene.Rdata"
#
# [[1461]]
# [1] "http://duffel.rail.bio/recount/v2/SRP048761/rse_gene.Rdata"
#
# [[1462]]
# [1] "http://duffel.rail.bio/recount/v2/SRP062023/rse_gene.Rdata"
#
# [[1463]]
# [1] "http://duffel.rail.bio/recount/v2/SRP041538/rse_gene.Rdata"
#
# [[1464]]
# [1] "http://duffel.rail.bio/recount/v2/SRP064131/rse_gene.Rdata"
#
# [[1465]]
# [1] "http://duffel.rail.bio/recount/v2/SRP039338/rse_gene.Rdata"
#
# [[1466]]
# [1] "http://duffel.rail.bio/recount/v2/SRP035599/rse_gene.Rdata"

# %% [markdown]
# # Normalize with RPKM

# %%
# get RPKM for each experiment and add to list
rpkm.list <- list()
for (experiment in included.sample.list) {
  load(file.path(data.dir, experiment, "rse_gene.Rdata"))
  rpkm <- as.data.frame(getRPKM(rse_gene))
  rpkm$id <- rownames(rpkm)
  rpkm.list[[experiment]] <- rpkm
}

# %%
# combine experiments -- this is the most memory efficient way to go about this
# that I've found -- will need to drop extraneous gene id columns
rpkm.df <- do.call(base::cbind, c(rpkm.list, by = "id"))
rpkm.df <- rpkm.df %>% dplyr::select(-dplyr::ends_with("id"))
rpkm.df <- tibble::rownames_to_column(rpkm.df, "ENSG")
# drop last column "by" -- information about what was used with base::cbind
rpkm.df <- rpkm.df %>% dplyr::select(-by)

# %% [markdown]
# # Save

# %%
output_filepath <- file.path(recount2full.data.dir, "recount2_rpkm_raw")

# %%
output_filepath
# Out:
# [1] "/opt/data/data/recount2full/recount2_rpkm_raw"

# %%
saveRDS(rpkm.df, file = paste0(output_filepath, ".rds"))
